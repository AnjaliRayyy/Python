# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
sns.barplot([[1,2,3,4,5],[3,4,5,6,7]])
# Out:
# <Axes: >

# %%
df=pd.read_csv('train.csv')
#df= df.sample(200)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.scatterplot(data=df,x='Age',y='Fare',hue='Sex',style='Pclass')
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
plt.scatter(df['Age'],df['Fare'])

# %%
plt.hist([df['Pclass']],bins=5)
arr=np.array(df['Pclass'])
val,cnt=np.unique_counts(arr)
plt.xticks(val,)
plt.show()

# %%
sns.barplot(data=df,x='Pclass',y='Age',hue='Sex')
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.boxplot(data=df,x='Sex',y='Age',hue='Survived')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.kdeplot(df[df["Survived"]==0],x='Age')
sns.kdeplot(df[df["Survived"]==1],x='Age')
# Out:
# <Axes: xlabel='Age', ylabel='Density'>
