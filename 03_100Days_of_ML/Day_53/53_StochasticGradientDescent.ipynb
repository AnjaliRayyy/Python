# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('../Day_52/advertising.csv')

# %% [markdown]
# ### Implementing Stochastic Gradient Descent from scratch

# %%
class SGDRegressor:
    def __init__(self,learning_rate=0.001,epochs=100):
        self.intercept_=None
        self.coef_= None
        self.lr = learning_rate
        self.epoch = epochs

    def fit(self,X,Y):
        X = X.to_numpy() if hasattr(X, "to_numpy") else X
        Y = Y.to_numpy() if hasattr(Y, "to_numpy") else Y
    
        self.intercept_=120
        self.coef_=np.ones(X.shape[1])

        for i in range(self.epoch):
            for j in range(X.shape[0]):
               
               idx=np.random.randint(0,X.shape[0])
               
               y_hat=self.intercept_ + np.dot(X[idx],self.coef_)
               intercept_der=-2 * (Y[idx]-y_hat)
               self.intercept_ = self.intercept_ - (self.lr * intercept_der)

               coef_der = -2 * np.dot(Y[idx]-y_hat,X[idx])
               self.coef_ =self.coef_ - (self.lr * coef_der)


    def predict(self,X):
        return np.dot(X,self.coef_)+self.intercept_

# %%
from sklearn.model_selection import train_test_split
X=df.iloc[:,:-1]
Y=df.iloc[:,-1]
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
mySGD=SGDRegressor(learning_rate=0.01,epochs=100)
mySGD.fit(X_train,Y_train)
predictions=mySGD.predict(X_test)

# %%
mySGD.intercept_
# Out:
# np.float64(15.154816332791626)

# %%
mySGD.coef_
# Out:
# array([4.81773141, 1.58841427, 0.05444803])

# %%
from sklearn.metrics import r2_score
r2_score(Y_test,predictions)
# Out:
# 0.9090130150125163
