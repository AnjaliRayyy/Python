# %%
import pandas as pd

# %%
import requests

url = "https://api.themoviedb.org/3/trending/movie/day?language=en-US"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI1OTE4NjkzZWFmM2M2ZGFjNDIwY2E1MjkyZWVjNDI4OSIsIm5iZiI6MTc2MjU4ODk3My45MTM5OTk4LCJzdWIiOiI2OTBlZjkyZGNhODMwYTZlYjFjZTgwNTAiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.uXBCTLRlHizeQcXkpIdj3tuxcfAkSoONrmHKTf2he78"
}

response = requests.get(url, headers=headers)

# %%
df=pd.DataFrame(response.json()['results'])[['id','title','overview','original_language','release_date','vote_average']]
df
# Out:
#          id                               title  \
# 0   1062722                        Frankenstein
# 1   1114967                        Good Fortune
# 2   1242898                  Predator: Badlands
# 3      7451                                 xXx
# 4   1561969                           Baramulla
# 5   1197137                       Black Phone 2
# 6   1571470            The Rats: A Witcher Tale
# 7    760329                The Smashing Machine
# 8   1446358                  Groom & Two Brides
# 9    617126        The Fantastic 4: First Steps
# 10  1252382           Tyler Perry's Finding Joy
# 11  1479945         Wicked: One Wonderful Night
# 12   967941                    Wicked: For Good
# 13   701387                             Bugonia
# 14  1084242                          Zootopia 2
# 15  1035259                       The Naked Gun
# 16  1280330                     Operation Hadal
# 17   425274       Now You See Me: Now You Don't
# ...

# %%
df[df['original_language']=='hi']
# Out:
#         id      title                                           overview  \
# 4  1561969  Baramulla  A police officer investigating missing childre...
#
#   original_language release_date  vote_average
# 4                hi   2025-11-07           0.0

# %%
df.sort_values(by='vote_average',ascending=False)
# Out:
#          id                               title  \
# 19  1218925  Chainsaw Man - The Movie: Reze Arc
# 13   701387                             Bugonia
# 0   1062722                        Frankenstein
# 16  1280330                     Operation Hadal
# 5   1197137                       Black Phone 2
# 18  1328803                     Prisoner of War
# 9    617126        The Fantastic 4: First Steps
# 2   1242898                  Predator: Badlands
# 1   1114967                        Good Fortune
# 15  1035259                       The Naked Gun
# 10  1252382           Tyler Perry's Finding Joy
# 7    760329                The Smashing Machine
# 17   425274       Now You See Me: Now You Don't
# 3      7451                                 xXx
# 6   1571470            The Rats: A Witcher Tale
# 4   1561969                           Baramulla
# 11  1479945         Wicked: One Wonderful Night
# 8   1446358                  Groom & Two Brides
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 20 non-null     int64
#  1   title              20 non-null     object
#  2   overview           20 non-null     object
#  3   original_language  20 non-null     object
#  4   release_date       20 non-null     object
#  5   vote_average       20 non-null     float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 1.1+ KB

# %%
df['release_date']=pd.to_datetime(df['release_date'],format='%Y-%m-%d',errors='coerce')

# %%
df['release_date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df.sort_values(by='release_date',ascending=False)
# Out:
#          id                               title  \
# 14  1084242                          Zootopia 2
# 12   967941                    Wicked: For Good
# 17   425274       Now You See Me: Now You Don't
# 4   1561969                           Baramulla
# 8   1446358                  Groom & Two Brides
# 11  1479945         Wicked: One Wonderful Night
# 10  1252382           Tyler Perry's Finding Joy
# 2   1242898                  Predator: Badlands
# 6   1571470            The Rats: A Witcher Tale
# 13   701387                             Bugonia
# 0   1062722                        Frankenstein
# 5   1197137                       Black Phone 2
# 1   1114967                        Good Fortune
# 7    760329                The Smashing Machine
# 18  1328803                     Prisoner of War
# 19  1218925  Chainsaw Man - The Movie: Reze Arc
# 15  1035259                       The Naked Gun
# 9    617126        The Fantastic 4: First Steps
# ...
