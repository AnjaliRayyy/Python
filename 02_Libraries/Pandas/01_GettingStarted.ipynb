# %%
import pandas as pd
import numpy as np

# %%
dict1={
    "name":["Anjali","Abhi","Harry","Rohan"],
    "marks":[96,90,88,65],
    "city":["Kolkata","Meerut","Bareily","Amritsar"]
}
df=pd.DataFrame(dict1)
df
# Out:
#      name  marks      city
# 0  Anjali     96   Kolkata
# 1    Abhi     90    Meerut
# 2   Harry     88   Bareily
# 3   Rohan     65  Amritsar

# %%
head=df.head(2)
head
# Out:
#      name  marks     city
# 0  Anjali     96  Kolkata
# 1    Abhi     90   Meerut

# %%
tail=df.tail(2)
tail
# Out:
#     name  marks      city
# 2  Harry     88   Bareily
# 3  Rohan     65  Amritsar

# %% [markdown]
# ### Exporting to csv

# %%
df.to_csv('friends.csv',index=False)

# %% [markdown]
# ### Importing a csv file

# %%
data=pd.read_csv('Data.csv')
data
# Out:
#     ID     Name  Age       City  Score
# 0    1   User_1   44     Mumbai     75
# 1    2   User_2   32    Chennai     85
# 2    3   User_3   45  Hyderabad     89
# 3    4   User_4   39  Hyderabad     84
# 4    5   User_5   32      Delhi     64
# 5    6   User_6   37  Bangalore     69
# 6    7   User_7   24    Chennai     61
# 7    8   User_8   44    Kolkata     74
# 8    9   User_9   39      Delhi     46
# 9   10  User_10   26    Kolkata     55
# 10  11  User_11   44    Chennai     55
# 11  12  User_12   36      Delhi     93
# 12  13  User_13   34    Kolkata     61
# 13  14  User_14   37    Kolkata     45
# 14  15  User_15   35    Kolkata     73
# 15  16  User_16   48  Bangalore     80
# 16  17  User_17   49    Kolkata     85
# 17  18  User_18   33     Mumbai     74
# 18  19  User_19   41     Mumbai     51
# 19  20  User_20   24  Hyderabad     50

# %%
data.describe()
# Out:
#              ID        Age      Score
# count  20.00000  20.000000  20.000000
# mean   10.50000  37.150000  68.450000
# std     5.91608   7.393276  14.982358
# min     1.00000  24.000000  45.000000
# 25%     5.75000  32.750000  55.000000
# 50%    10.50000  37.000000  71.000000
# 75%    15.25000  44.000000  81.000000
# max    20.00000  49.000000  93.000000

# %%
data.head(5)
# Out:
#    ID    Name  Age       City  Score
# 0   1  User_1   44     Mumbai     75
# 1   2  User_2   32    Chennai     85
# 2   3  User_3   45  Hyderabad     89
# 3   4  User_4   39  Hyderabad     84
# 4   5  User_5   32      Delhi     64

# %%
series=pd.Series([1,2,3,4,5,6],index=["first","second","third",'fourth','fifth','sixth'])
series
# Out:
# first     1
# second    2
# third     3
# fourth    4
# fifth     5
# sixth     6
# dtype: int64

# %%
newdf=pd.DataFrame(np.random.rand(100,5)*100,index=np.arange(1,101),columns=np.arange(1,6))
newdf
# Out:
#              1          2          3          4          5
# 1    41.147538  76.517783  24.850479  92.572171  29.327686
